# %%
pip install gymnasium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gymnasium as gym
env = gym.make('CartPole-v1')

# %%
pip install swig
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#pip install gymnasium[box2d]

# %%
#conda install -c conda-forge box2d-py in anaconda terminal
#conda install -c conda-forge pygame in terminal

# %% [markdown]
# Solution 6: Ensure Required Build Tools Are Installed
# On Windows, installing box2d-py may require a compiler. Install Microsoft Visual C++ Build Tools:
#
# Download and install Microsoft Visual Studio Build Tools.
# During installation, select the C++ build tools workload.
# Restart your system after installation.

# %%
import gymnasium as gym
import pygame

env = gym.make("LunarLander-v3", render_mode="rgb_array")
observation, info = env.reset()

# Get frame size from env.render()
frame = env.render()
height, width, _ = frame.shape

pygame.init()
screen = pygame.display.set_mode((width, height))

episode_over = False
while not episode_over:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            exit()

    frame = env.render()
    surface = pygame.surfarray.make_surface(frame.swapaxes(0, 1))
    screen.blit(surface, (0, 0))
    pygame.display.flip()

    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    episode_over = terminated or truncated

env.close()
pygame.quit()

# %%
#multiple episode
import gymnasium as gym
import pygame

env = gym.make("LunarLander-v3", render_mode="rgb_array")
#env = gym.make("CarRacing-v3", render_mode="rgb_array")
#env = gym.make("FrozenLake-v1", render_mode="rgb_array")
#env = gym.make("CliffWalking", render_mode="rgb_array")
#env = gym.make("CartPole-v1", render_mode="rgb_array")
#env = gym.make("MountainCar-v0", render_mode="rgb_array")
pygame.init()
# Get frame size from env.render() after reset
observation, info = env.reset()
frame = env.render()
height, width, _ = frame.shape
screen = pygame.display.set_mode((width, height))

num_episodes = 10  # Change this to run more episodes
for episode in range(num_episodes):
    observation, info = env.reset()
    episode_over = False

    while not episode_over:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                exit()

        frame = env.render()
        surface = pygame.surfarray.make_surface(frame.swapaxes(0, 1))
        screen.blit(surface, (0, 0))
        pygame.display.flip()

        action = env.action_space.sample()
        observation, reward, terminated, truncated, info = env.step(action)
        episode_over = terminated or truncated

env.close()
pygame.quit()

# %%
import gymnasium as gym
import pygame

# Change this to "rgb_array" or "human"
#render_mode = "rgb_array"   # or "human"
render_mode = "human"
env = gym.make("LunarLander-v3", render_mode=render_mode)

if render_mode == "rgb_array":
    # Initialize pygame only if we need to display frames manually
    observation, info = env.reset()
    frame = env.render()
    height, width, _ = frame.shape

    pygame.init()
    screen = pygame.display.set_mode((width, height))

    num_episodes = 2
    for episode in range(num_episodes):
        observation, info = env.reset()
        episode_over = False

        while not episode_over:
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    pygame.quit()
                    exit()

            frame = env.render()
            surface = pygame.surfarray.make_surface(frame.swapaxes(0, 1))
            screen.blit(surface, (0, 0))
            pygame.display.flip()

            action = env.action_space.sample()
            observation, reward, terminated, truncated, info = env.step(action)
            episode_over = terminated or truncated

    pygame.quit()

else:  # render_mode == "human"
    num_episodes = 2
    for episode in range(num_episodes):
        observation, info = env.reset()
        episode_over = False

        while not episode_over:
            action = env.action_space.sample()
            observation, reward, terminated, truncated, info = env.step(action)
            episode_over = terminated or truncated

env.close()

# %% [markdown]
# Modifying the environment

# %%
from gymnasium.wrappers import FlattenObservation
env = gym.make("CarRacing-v3")
env.observation_space.shape
# Out:
# (96, 96, 3)

# %%
wrapped_env = FlattenObservation(env)
wrapped_env.observation_space.shape
# Out:
# (27648,)
